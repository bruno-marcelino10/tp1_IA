# %% [markdown]
# # Enunciado

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # 1. Estruturas Utilizadas

# %% [markdown]
# # 2. Principais Diferenças Entre os Algoritmos

# %% [markdown]
# # 3. Heurística Utilizada

# %% [markdown]
# # 4. Exemplos de Soluções Encontradas Pelos Algoritmos

# %% [markdown]
# # 5. Análise Quantitativa dos Algoritmos

# %% [markdown]
# # 6. Resultados e Discussões
